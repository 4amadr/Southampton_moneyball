# %%
import pandas as pd

df = pd.read_csv('C:/Users/vitor/OneDrive/Documentos/My-projects/Southampton/PL_data.csv')
df
# Out:
#          Player Name                     Club Nationality Position  \
# 0          Ben White                  Arsenal     England      DEF
# 1        Bukayo Saka                  Arsenal     England      MID
# 2         David Raya                  Arsenal       Spain      GKP
# 3        Declan Rice                  Arsenal     England      MID
# 4      Ethan Nwaneri                  Arsenal     England      MID
# ..               ...                      ...         ...      ...
# 523   Santiago Bueno  Wolverhampton Wanderers     Uruguay      DEF
# 524         Tom King  Wolverhampton Wanderers       Wales      GKP
# 525      Tommy Doyle  Wolverhampton Wanderers     England      MID
# 526       Toti Gomes  Wolverhampton Wanderers    Portugal      DEF
# 527  Yerson Mosquera  Wolverhampton Wanderers    Colombia      DEF
#
#      Appearances  Minutes  Goals  Assists  Shots  Shots On Target  ...  \
# 0             17     1198      0        2      9               12  ...
# 1             25     1735      6       10     67                2  ...
# 2             38     3420      0        0      0                0  ...
# 3             35     2833      4        7     48               18  ...
# 4             26      889      4        0     24                0  ...
# ..           ...      ...    ...      ...    ...              ...  ...
# 523           29     1682      0        0      6                3  ...
# 524            1        1      0        0      0                0  ...
# 525           24      475      0        1      9                0  ...
# 526           31     2615      0        0      7                8  ...
# 527            5      442      0        0      2                0  ...
#
#     Condução por 90m  Condução ao ataque por 90m  Assistencias por 90m  \
# 0          43.797997                   22.237062              0.150250
# 1           8.662824                    3.579251              0.518732
# 2           0.000000                    0.000000              0.000000
# 3          13.056830                    8.259795              0.222379
# 4           0.000000                    0.000000              0.000000
# ..               ...                         ...                   ...
# 523        15.624257                    7.705113              0.000000
# 524         0.000000                    0.000000              0.000000
# 525         0.000000                    0.000000              0.189474
# 526        12.045889                    6.539197              0.000000
# 527         0.000000                    0.000000              0.000000
#
#      Conduções que geraram assistencia por 90m  Eficacia com a bola  \
# 0                                    22.387312            17.833333
# 1                                     4.097983             1.100000
# 2                                     0.000000                  NaN
# 3                                     8.482174             3.781250
# 4                                     0.000000             0.000000
# ..                                         ...                  ...
# 523                                   7.705113            54.500000
# 524                                   0.000000                  NaN
# 525                                   0.189474             0.000000
# 526                                   6.539197             8.800000
# 527                                   0.000000                  NaN
#
#      Gols por 90m  Chutes por 90m Chutes ao gol por 90m  \
# 0        0.000000        0.676127              0.901503
# 1        0.311239        3.475504              0.103746
# 2        0.000000        0.000000              0.000000
# 3        0.127074        1.524885              0.571832
# 4        0.404949        2.429696              0.000000
# ..            ...             ...                   ...
# 523      0.000000        0.321046              0.160523
# 524      0.000000        0.000000              0.000000
# 525      0.000000        1.705263              0.000000
# 526      0.000000        0.240918              0.275335
# 527      0.000000        0.407240              0.000000
#
#      Grandes chances perdidas por 90m  Gols por Assistência
# 0                            0.000000              0.000000
# 1                            0.414986              0.600000
# 2                            0.000000                   NaN
# 3                            0.063537              0.571429
# 4                            0.000000                   NaN
# ..                                ...                   ...
# 523                          0.000000                   NaN
# 524                          0.000000                   NaN
# 525                          0.189474              0.000000
# 526                          0.034417                   NaN
# 527                          0.203620                   NaN
#
# [528 rows x 79 columns]

# %%
# Calculando médias
desarmes_media = df['Tackles'].mean()
duelos_no_chao_media = df['Ground Duels'].mean()
bolas_zeradas_media = df['Bolas zeradas po 90m'].mean()
intercept_media = df['Interceptions'].mean()
eficacia_media = df['Eficacia com a bola'].mean()
versatilidade_media = df['Versatilidade defensiva'].mean()
clubes_indesejados = ['Arsenal', 'Chelsea', 'Manchester United', 'Manchester City', 'Tottenham Hotspur', 'Liverpool']

# Aplicando filtro para defensores
defensor_ideal = df[
    (~df['Club'].isin(clubes_indesejados)) &
    (df['Position'] == 'DEF') &
    (df['Tackles'] >= desarmes_media) &
    (df['Interceptions'] >= intercept_media) &
    (df['Eficacia com a bola'] >= eficacia_media) &
    (df['Versatilidade defensiva'] >= versatilidade_media) &
    (df['Ground Duels'] >= duelos_no_chao_media) &
    (df['Bolas zeradas po 90m'] >= bolas_zeradas_media)
]
defensor_ideal.to_csv('defensor_ideal.csv')

# %%
print(defensor_ideal.head(15))
# Out:
#             Player Name                     Club    Nationality Position  \
# 208  Jarrad Branthwaite                  Everton        England      DEF
# 397        Fabian Schär         Newcastle United    Switzerland      DEF
# 469   Aaron Wan-Bissaka          West Ham United        England      DEF
# 504    Emmanuel Agbadou  Wolverhampton Wanderers  Cote D’Ivoire      DEF
# 523      Santiago Bueno  Wolverhampton Wanderers        Uruguay      DEF
# 526          Toti Gomes  Wolverhampton Wanderers       Portugal      DEF
#
#      Appearances  Minutes  Goals  Assists  Shots  Shots On Target  ...  \
# 208           30     2510      0        1     10               37  ...
# 397           34     2937      4        0     40               12  ...
# 469           36     3154      2        5     16                5  ...
# 504           16     1411      1        0      7               20  ...
# 523           29     1682      0        0      6                3  ...
# 526           31     2615      0        0      7                8  ...
#
#     Condução por 90m  Condução ao ataque por 90m  Assistencias por 90m  \
# 208        13.266932                    7.673307              0.035857
# 397         6.925434                    3.646578              0.000000
# 469        11.785035                    7.162334              0.142676
# 504        26.470588                   11.545004              0.000000
# 523        15.624257                    7.705113              0.000000
# 526        12.045889                    6.539197              0.000000
#
#      Conduções que geraram assistencia por 90m  Eficacia com a bola  \
# 208                                   7.709163            32.250000
# 397                                   3.646578            13.166667
# 469                                   7.305010             7.909091
# 504                                  11.545004            39.000000
# 523                                   7.705113            54.500000
# 526                                   6.539197             8.800000
#
#      Gols por 90m  Chutes por 90m Chutes ao gol por 90m  \
# 208      0.000000        0.358566              1.326693
# 397      0.122574        1.225741              0.367722
# 469      0.057070        0.456563              0.142676
# 504      0.063785        0.446492              1.275691
# 523      0.000000        0.321046              0.160523
# 526      0.000000        0.240918              0.275335
#
#      Grandes chances perdidas por 90m  Gols por Assistência
# 208                          0.071713                   0.0
# 397                          0.122574                   NaN
# 469                          0.028535                   0.4
# 504                          0.000000                   NaN
# 523                          0.000000                   NaN
# 526                          0.034417                   NaN
#
# [6 rows x 79 columns]

# %%
# removendo valores de porcentagem
df['fThird Passes %'] = df['fThird Passes %'].str.replace('%', '').astype(float) / 100

# %%
# identificando alvos para o meio campo
media_assistencias = df['Assists'].mean()
passes_parte_final_media = df['fThird Passes %'].mean()
quebra_de_linha_media_por_jogo = df['Quebra de linha por 90m'].mean()
eficacia_com_bola_media = df['Eficacia com a bola'].mean()
assistencia_por_90m = df['Assistencias por 90m'].mean()
conducao_e_assistencia_90m = df['Conduções que geraram assistencia por 90m'].mean()
conducao_ao_ataque = df['Progressive Carries'].mean()
eficacia = df['Eficacia com a bola'].mean()
conducao_por_90m = df['Condução por 90m'].mean()




# Clubes de jogadores descartados por conter jogadores superfaturados
clubes_indesejados = ['Arsenal', 'Chelsea', 'Manchester United', 'Manchester City', 'Tottenham Hotspur', 'Liverpool']


meias_ideais = df[
    (~df['Club'].isin(clubes_indesejados)) &
    (df['Conduções que geraram assistencia por 90m'] > conducao_e_assistencia_90m) &
    (df['Progressive Carries'] > conducao_ao_ataque) &
    (df['Condução por 90m'] > conducao_por_90m) &
    (df['Eficacia com a bola'] > eficacia) &
    (df['Position'] == 'MID') &
    (df['Assists'] > media_assistencias) &
    (df['fThird Passes %'] > passes_parte_final_media) &
    (df['Quebra de linha por 90m'] > quebra_de_linha_media_por_jogo) &
    (df['Eficacia com a bola'] > eficacia_com_bola_media) &
    (df['Assistencias por 90m'] > assistencia_por_90m)
]
meias_ideais.head(15)

meias_ideais.to_csv('meias_filtrados.csv')

# %%
# removendo valores de porcentagem
df['Conversion %'] = df['Conversion %'].str.replace('%', '').astype(float) / 100

# %%
# analise de atacantes ideais
chutes_no_gol = df['Shots On Target'].mean()
conversao_porcentagem = df['Conversion %'].mean()
media_gols_por_jogo = df['Gols por 90m'].mean()
chutes_gol_por_jogo = df['Chutes ao gol por 90m'].mean()


atacantes_ideais = df[
    (~df['Club'].isin(clubes_indesejados)) &
    (df['Position'] == 'FWD') &
    (df['Shots On Target'] > chutes_no_gol) &
    (df['Conversion %'] > conversao_porcentagem) &
    (df['Gols por 90m'] > media_gols_por_jogo) &
    (df['Chutes ao gol por 90m'] > chutes_gol_por_jogo)
    ]

print(atacantes_ideais.head(15))
atacantes_ideais.to_csv('atacantes_filtrados.csv', index=False)
# Out:
#                Player Name              Club    Nationality Position  \
# 46           Ollie Watkins       Aston Villa        England      FWD
# 107            Yoane Wissa         Brentford       DR Congo      FWD
# 194         Adam Armstrong           Everton        England      FWD
# 197                   Beto           Everton  Guinea-Bissau      FWD
# 199  Dominic Calvert-Lewin           Everton        England      FWD
# 238          Rodrigo Muniz            Fulham         Brazil      FWD
# 391         Alexander Isak  Newcastle United         Sweden      FWD
#
#      Appearances  Minutes  Goals  Assists  Shots  Shots On Target  ...  \
# 46            38     2610     16        8     84               17  ...
# 107           35     2927     19        0     90               13  ...
# 194           20     1252      2        2     26                9  ...
# 197           30     1528      8        0     49                7  ...
# 199           26     1613      3        1     50               26  ...
# 238           31      951      8        1     39               12  ...
# 391           34     2769     23        0     99               14  ...
#
#      Condução por 90m  Condução ao ataque por 90m  Assistencias por 90m  \
# 46           4.965517                    2.862069              0.275862
# 107         11.684318                    5.534677              0.000000
# 194          6.829073                    3.019169              0.143770
# 197         18.435864                    9.188482              0.000000
# 199          8.760074                    4.128952              0.055797
# 238         24.605678                   11.924290              0.094637
# 391          7.703142                    4.290358              0.000000
#
#      Conduções que geraram assistencia por 90m  Eficacia com a bola  \
# 46                                    3.137931             0.740000
# 107                                   5.534677             4.142857
# 194                                   3.162939             1.277778
# 197                                   9.188482             2.486486
# 199                                   4.184749             1.151515
# 238                                  12.018927             7.583333
# 391                                   4.290358             2.690909
#
#      Gols por 90m  Chutes por 90m Chutes ao gol por 90m  \
# 46       0.551724        2.896552              0.586207
# 107      0.584216        2.767339              0.399727
# 194      0.143770        1.869010              0.646965
# 197      0.471204        2.886126              0.412304
# 199      0.167390        2.789833              1.450713
# 238      0.757098        3.690852              1.135647
# 391      0.747562        3.217768              0.455038
#
#      Grandes chances perdidas por 90m  Gols por Assistência
# 46                           0.931034                   2.0
# 107                          0.522720                   NaN
# 194                          0.359425                   1.0
# 197                          0.706806                   NaN
# 199                          0.892746                   3.0
# 238                          0.473186                   8.0
# 391                          0.585049                   NaN
#
# [7 rows x 79 columns]

# %%
atacantes = pd.read_csv('atacantes_filtrados.csv')
atacantes
# Out:
#              Player Name         Club Nationality Position  Appearances  \
# 0          Ollie Watkins  Aston Villa     England      FWD           38
# 1  Dominic Calvert-Lewin      Everton     England      FWD           26
# 2          Rodrigo Muniz       Fulham      Brazil      FWD           31
#
#    Minutes  Goals  Assists  Shots  Shots On Target  ...  Condução por 90m  \
# 0     2610     16        8     84               17  ...          4.965517
# 1     1613      3        1     50               26  ...          8.760074
# 2      951      8        1     39               12  ...         24.605678
#
#    Condução ao ataque por 90m  Assistencias por 90m  \
# 0                    2.862069              0.275862
# 1                    4.128952              0.055797
# 2                   11.924290              0.094637
#
#    Conduções que geraram assistencia por 90m  Eficacia com a bola  \
# 0                                   3.137931             0.740000
# 1                                   4.184749             1.151515
# 2                                  12.018927             7.583333
#
#    Gols por 90m  Chutes por 90m Chutes ao gol por 90m  \
# 0      0.551724        2.896552              0.586207
# 1      0.167390        2.789833              1.450713
# 2      0.757098        3.690852              1.135647
#
#    Grandes chances perdidas por 90m  Gols por Assistência
# 0                          0.931034                   2.0
# 1                          0.892746                   3.0
# 2                          0.473186                   8.0
#
# [3 rows x 79 columns]
